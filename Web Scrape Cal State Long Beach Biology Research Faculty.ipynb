# %%
import requests

page = requests.get("http://web.csulb.edu/depts/biology/research.htm")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "http://web.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">\n<html xmlns="http://web.w3.org/1999/xhtml" lang="en"><!-- InstanceBegin template="/Templates/ut.dwt" codeOutsideHTMLIsLocked="false" -->\n<head>\n<!-- (c) 2007 Copyright - All Rights Reserved - California State University, Long Beach.\nUniversity Public Affairs & Publications office. For documentation and usage policy please visit www.csulb.edu/style/ -->\n<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1" />\n<!-- InstanceBeginEditable name="doctitle" -->\n<title>Research</title>\n<!-- InstanceEndEditable -->\n<meta name="description" content="California State University, Long Beach" />\n<meta name="keywords" content="California State University, Long Beach" />\n<meta name="language" content="en" />\n<script type="text/javascript" language="javascript">\n// Added config.html, contains config parameters for suggest in search, Pritesh Shah 04/27/2007\n// If you wish to turn off the suggestion feature for the search box, set suggest_in_search = false; \nvar suggest_in_search = true;\nvar xmlpath = \'/depts/biology/xml/keywords.xml\';\n</script>\n\n<script type="text/javascript" src="http://www.csulb.edu/misc/depot/js/dt-styleswitcher.js"></script>\n<!--<script language="JavaScript" type="text/javascript" src="/misc/depot/js/dynmenu.js"></script>-->\n<script type="text/javascript" src="http://www.csulb.edu/js/BreadCrumbs.js "></script>\n<script type="text/javascript">\nfunction load_this(){\ninsertSearchBox();\n// Make search enabled by default\nif(typeof suggest_in_search == \'undefined\' || suggest_in_search == true){\n\tInstallAC(document.getElementById("searchbox"),document.getElementById("SiteSearch"),document.getElementById("btnG"),"search","en");\n\t}\n}\n</script>\n<script type="text/javascript" src="http://www.csulb.edu/js/insearch_suggest.js"></script>\n<script type="text/javascript" src="http://www.csulb.edu/js/final_ac.js"></script>\n<script type="text/javascript" src="http://www.csulb.edu/misc/depot/js/ut_menu.js"></script>\n<script type="text/javascript" src="http://www.csulb.edu/js/swfobject.js"></script>\n\n\n<!--\n<script type="text/javascript">\n\n  var _gaq = _gaq || [];\n  _gaq.push([\'_setAccount\', \'UA-193316-2\']);\n  _gaq.push([\'_trackPageview\']);\n\n  (function() {\n    var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n    ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'http://www\') + \'.google-analytics.com/ga.js\';\n    var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n  })();\n\n</script>\n-->\n\n<link href="http://www.csulb.edu/misc/depot/css/ut-print.css" rel="stylesheet" type="text/css" media="print"/>\n<link href="http://www.csulb.edu/misc/depot/css/ut-medium.css" rel="stylesheet" type="text/css"/> <!-- 4/20/07 added by jhurtado to start with medium text size -->\n<link rel="alternate stylesheet" type="text/css" media="screen,print" href="http://www.csulb.edu/misc/depot/css/ut-small.css" title="small_text"/>\n<link rel="alternate stylesheet" type="text/css" media="screen,print" href="http://www.csulb.edu/misc/depot/css/ut-medium.css" title="medium_text"/>\n<link rel="alternate stylesheet" type="text/css" media="screen,print" href="http://www.csulb.edu/misc/depot/css/ut-large.css" title="large_text"/>\n<link href="/depts/biology/assets/ut/ut.css" media="screen" rel="stylesheet" type="text/css" />\n<link href="/depts/biology/css/website.css" rel="stylesheet" type="text/css" />\n<link href="/depts/biology/css/dropdown.css" rel="stylesheet" type="text/css" />\n<script type="text/javascript" src="/depts/biology/js/dropdown.js"></script>\n<link href="css/local.css" rel="stylesheet" type="text/css" />\n<script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>\n<script src="/depts/biology/js/ada.js" type="text/javascript" ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "http://web.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html lang="en" xmlns="http://web.w3.org/1999/xhtml">
#  <!-- InstanceBegin template="/Templates/ut.dwt" codeOutsideHTMLIsLocked="false" -->
#  <head>
#   <!-- (c) 2007 Copyright - All Rights Reserved - California State University, Long Beach.
# University Public Affairs & Publications office. For documentation and usage policy please visit www.csulb.edu/style/ -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- InstanceBeginEditable name="doctitle" -->
#   <title>
#    Research
#   </title>
#   <!-- InstanceEndEditable -->
#   <meta content="California State University, Long Beach" name="description"/>
#   <meta content="California State University, Long Beach" name="keywords"/>
#   <meta content="en" name="language"/>
#   <script language="javascript" type="text/javascript">
#    // Added config.html, contains config parameters for suggest in search, Pritesh Shah 04/27/2007
# // If you wish to turn off the suggestion feature for the search box, set suggest_in_search = false;
# var suggest_in_search = true;
# var xmlpath = '/depts/biology/xml/keywords.xml';
#   </script>
#   <script src="http://www.csulb.edu/misc/depot/js/dt-styleswitcher.js" type="text/javascript">
#   </script>
#   <!--<script language="JavaScript" type="text/javascript" src="/misc/depot/js/dynmenu.js"></script>-->
#   <script src="http://www.csulb.edu/js/BreadCrumbs.js " type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function load_this(){
# insertSearchBox();
# // Make search enabled by default
# if(typeof suggest_in_search == 'undefined' || suggest_in_search == true){
# 	InstallAC(document.getElementById("searchbox"),document.getElementById("SiteSearch"),document.getElementById("btnG"),"search","en");
# 	}
# }
#   </script>
#   <script src="http://www.csulb.edu/js/insearch_suggest.js" type="text/javascript">
#   </script>
#   <script src="http://www.csulb.edu/js/final_ac.js" type="text/javascript">
#   </script>
#   <script src="http://www.csulb.edu/misc/depot/js/ut_menu.js" type="text/javascript">
#   </script>
#   <script src="http://www.csulb.edu/js/swfobject.js" type="text/javascript">
#   </script>
#   <!--
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-193316-2']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# -->
#   <link href="http://www.csulb.edu/misc/depot/css/ut-print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="http://www.csulb.edu/misc/depot/css/ut-medium.css" rel="stylesheet" type="text/css"/>
#   <!-- 4/20/07 added by jhurtado to start with medium text size -->
#   <link href="http://www.csulb.edu/misc/depot/css/ut-small.css" media="screen,print" rel="alternate stylesheet" title="small_text" type="text/css"/>
#   <link href="http://www.csulb.edu/misc/depot/css/ut-medium.css" media="screen,print" rel="alternate stylesheet" title="medium_text" type="text/css"/>
#   <link href="http://www.csulb.edu/misc/depot/css/ut-large.css" media="screen,print" rel="alternate stylesheet" title="large_text" type="text/css"/>
#   <link href="/depts/biology/assets/ut/ut.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/depts/biology/css/website.css" rel="stylesheet" type="text/css"/>
#   <link href="/depts/biology/css/dropdown.css" rel="stylesheet" type="text/css"/>
#   <script src="/depts/biology/js/dropdown.js" type="text/javascript">
#   </script>
#   <link href="css/local.css" rel="stylesheet" type="text/css"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">
#   </script>
#   <script src="/depts/biology/js/ada.js" type="text/javascript">
#   </script>
#   <link href="/depts/biology/images/favicon.ico" rel="shortcut icon"/>
#   <!-- InstanceBeginEditable name="head" -->
#   <!-- InstanceEndEditable -->
#   <!-- InstanceParam name="body" type="text" value="home" -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55481155-1', 'auto');
#   ga('send', 'pageview');
#   </script>
#  </head>
#  <body class="home">
#   <div class="clear_float">
#    <a href="#localnav">
#     Skip to Local Navigation
#    </a>
#   </div>
#   <div class="clear_float">
#    <a href="#content">
#     Skip to Content
#    </a>
#   </div>
#   <div id="contain_header">
#    <div id="contain_header_setwidth">
#     <div id="contain_siteid">
#      <div id="siteid_content">
#       <a href="/">
#        <img alt="California State University, Long Beach" height="50" src="http://www.csulb.edu/misc/depot/assets/UT/hdr_blk_id.gif" title="California State University, Long Beach" width="287"/>
#       </a>
#      </div>
#     </div>
#     <div id="contain_search">
#      <div id="content_searchtools">
#       <ul id="searchtools_links">
#        <li>
#         <!--<form action="http://www.google.com/cse">
#   <input type="hidden" name="cx" value="008228339182088589610:7g2hkai1j4c" />
#   <label class="hidden" for="SiteSearch">Search CSULB</label>
#   <input name="q" class="sitesearchbox" id="SiteSearch" alt="Search CSULB" tabindex="1" size="16" maxlength="120" />
#   <input type="image" class="sitesearchbutton" src="/images/interface/searchbutton_icon.gif" width="45" height="21" tabindex="2" alt="Search" />
#   <input type="hidden" name="cof" value="FORID:0" />
# </form>-->
#         <div id="gSearchbox">
#          <form action="http://www.google.com/cse" id="searchbox">
#           <input name="cx" type="hidden" value="008228339182088589610:7g2hkai1j4c"/>
#           <label class="hidden" for="SiteSearch">
#            Search CSULB
#           </label>
#           <input alt="Search CSULB" class="sitesearchbox" id="SiteSearch" maxlength="120" name="q" size="14" tabindex="1" value="Search"/>
#           <input alt="Search" class="sitesearchbutton" src="http://www.csulb.edu/images/interface/searchbutton_icon.gif" tabindex="2" type="image"/>
#           <input name="cof" type="hidden" value="FORID:0"/>
#          </form>
#         </div>
#        </li>
#        <li class="searchtools_text">
#         <a href="/help">
#          Help
#         </a>
#         <span class="v_separator">
#         </span>
#        </li>
#        <li class="searchtools_text">
#         <a href="/sitemap">
#          Index
#         </a>
#         <span class="v_separator">
#         </span>
#        </li>
#        <li class="searchtools_text">
#         <a href="/search">
#          Directory
#         </a>
#         <span class="v_separator">
#         </span>
#        </li>
#        <li class="searchtools_text">
#         <a href="/maps">
#          Maps
#         </a>
#         <span class="v_separator">
#         </span>
#        </li>
#        <li class="searchtools_text">
#         <a href="https://bbcsulb.desire2learn.com">
#          Beachboard
#         </a>
#         <span class="v_separator">
#         </span>
#        </li>
#        <li class="searchtools_text">
#         <a href="https://my.cms.csulb.edu">
#          MyCSULB
#         </a>
#         <span class="v_separator">
#         </span>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="clear_float">
#     </div>
#    </div>
#   </div>
#   <div id="contain_banner_secondary">
#    <a href="/depts/biology/index.htm">
#     <img alt="Biological Sciences Banner" border="0" height="100" src="/depts/biology/assets/banners/nu_biobanner.jpg" title="Biological Sciences Banner" width="900"/>
#    </a>
#   </div>
#   <div id="contain_divisionnav">
#    <div id="divisionnav_content">
#     <ul class="jsoff" id="ddmenu">
#      <li>
#       <a class="mum" href="#">
#        Department Info
#       </a>
#       <ul>
#        <li>
#         <a href="/depts/biology/about/contact.htm">
#          Contact
#         </a>
#        </li>
#        <li>
#         <a href="/depts/biology/about/mission.htm">
#          Mission Statement
#         </a>
#        </li>
#        <li>
#         <a href="/depts/biology/about/slo.htm">
#          Student Learning Outcomes
#         </a>
#        </li>
#        <li>
#         <a href="/depts/biology/about/seminar.htm">
#          Seminar Series
#         </a>
#        </li>
#        <li>
#         <a href="http://www.csulb.edu/colleges/cnsm/">
#          College of Natural Sciences and Mathematics
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a class="mum">
#        Students
#       </a>
#       <ul>
#        <li>
#         <a class="mum" href="#">
#          Undergraduates
#         </a>
#         <ul>
#          <li>
#           <a href="/depts/biology/students/options.htm">
#            Degree Options
#           </a>
#          </li>
#          <li>
#           <a href="/depts/biology/students/advising.htm">
#            Advising
#           </a>
#          </li>
#          <li>
#           <a href="http://web.csulb.edu/colleges/cnsm/students/tutoring.html">
#            Tutoring
#           </a>
#          </li>
#         </ul>
#         <li>
#          <a class="mum" href="#">
#           Graduates
#          </a>
#          <ul>
#           <li>
#            <a class="mum" href="#">
#             Programs
#            </a>
#            <ul>
#             <li>
#              <a href="/depts/biology/students/msbiolmicr_apply.htm">
#               M.S. Biology
#              </a>
#             </li>
#             <li>
#              <a href="/depts/biology/students/msbiolmicr_apply.htm">
#               M.S. Microbiology
#              </a>
#             </li>
#            </ul>
#            <li>
#             <a href="/depts/biology/employment/info.htm">
#              TA/GA Jobs
#             </a>
#            </li>
#            <li>
#             <a href="/depts/biology/students/tagainfo.htm">
#              TA/GA Links
#             </a>
#            </li>
#           </li>
#          </ul>
#         </li>
#        </li>
#        <li>
#         <a href="/depts/biology/students/scholarships.htm">
#          Scholarships
#         </a>
#        </li>
#        <li>
#         <a class="mum" href="#">
#          Internships &amp; Certificates
#         </a>
#         <ul>
#          <li>
#           <a href="http://www.csulb.edu/colleges/cnsm/students/internships/">
#            Internships
#           </a>
#          </li>
#          <li>
#           <a href="/depts/biology/students/biotech.htm">
#            Biotechnology Certificate
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="http://www.csulb.edu/depts/enrollment/registration/class_schedule/" target="_blank">
#          Schedule of Classes
#         </a>
#        </li>
#        <li>
#         <a href="http://www.csulb.edu/divisions/aa/catalog/current/cnsm/biology/biol_ld.html" target="_blank">
#          Course Catalog
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a class="mum" href="#">
#        People
#       </a>
#       <ul>
#        <li>
#         <a href="/depts/biology/people/faculty.htm">
#          Faculty
#         </a>
#        </li>
#        <li>
#         <a href="/depts/biology/people/staff.htm">
#          Staff
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a class="mum" href="#">
#        Research
#       </a>
#       <ul>
#        <li>
#         <a href="/depts/biology/research.htm">
#          Faculty Research
#         </a>
#        </li>
#        <li>
#         <a href="http://www.csulb.edu/colleges/cnsm/research/facilities.html">
#          Facilities
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a class="mum" href="#">
#        Employment
#       </a>
#       <ul>
#        <li>
#         <a href="/depts/biology/employment/info.htm">
#          Tenure Track
#         </a>
#        </li>
#        <li>
#         <a class="mum" href="#">
#          Lecturers
#         </a>
#         <ul>
#          <li>
#           <a href="/depts/biology/employment/info.htm">
#            Full Time Lecturers
#           </a>
#          </li>
#          <li>
#           <a href="http://www.csulb.edu/depts/biology/employment/forms/PTL-BIOL-PD-2238-FINAL.pdf">
#            Part Time Lecturers
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="http://www.csulb.edu/employment/">
#          Staff
#         </a>
#        </li>
#        <li>
#         <a href="/depts/biology/employment/info.htm">
#          TA/GA
#         </a>
#        </li>
#       </ul>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div id="container">
#    <div id="contain_content">
#     <a id="localnav" name="localnav">
#     </a>
#     <div id="contain_column1">
#      <!--	<ul>
#   		<h2 class="menudivider">Biological Sciences</h2>
#         <li class="home"><a href="/depts/biology/">Home</a></li>
#         <li class="home"><a href="/depts/biology/">Our Faculty</a></li>
#   		<li class="contact"><a href="/depts/biology/contact/">Contact Us</a></li>
# 	</ul>
#
# <h2 class="menudivider">Prospective Students</h2>
#
# 	<ul>
# 		<li class="baseline"><a href="/depts/biology/variations/typography/">Undergraduate Programs</a></li>
# 		<li class="color"><a href="/depts/biology/variations/color/">Graduate Programs</a></li>
# 		<li class="tables"><a href="/depts/biology/variations/tables/">Faculty Research</a></li>
# 		<li class="forms"><a href="/depts/biology/variations/forms/">Forms</a></li>
# 	</ul>
#
# <h2 class="menudivider">Current Students</h2>
#
# 	<ul>
#       	<li class="tcolumnnav"><a href="/depts/biology/variations/tcolnav/">Advising Schedule</a></li>
#         <li class="variations"><a href="/depts/biology/variations/">Course Schedule</a></li>
# 		<li class="grid"><a href="/depts/biology/variations/grid/">Course Catalog</a></li>
# 		<li class="default"><a href="/depts/biology/variations/default/">Seminar Series</a></li>
# 		<li class="onecolnav"><a href="/depts/biology/variations/1colnav/">Biotechnology Certificate</a></li>
# 	</ul>
#
#     <h2 class="menudivider">Sidebar</h2>
# 	<ul>
# 		<li class="empty"><a href="/depts/biology/variations/1col/">One Column Without Navigation</a></li>
# 		<li class="empty"><a href="/depts/biology/variations/2col/">Two Columns Without Navigation</a></li>
# 	  	<li class="tcolumn"><a href="/depts/biology/variations/tcol/">"T" Setup Without Navigation</a></li>
#
# 	</ul>
#
# <h2 class="menudivider">Nested Navigation</h2>
#
# <ul>
#   <li><h3>Nested Navigation Sample</h3>
#     <ul>
#       <li><h4>Sub Menu</h4>
# 		  <ul>
#
# 			  <li><a href="#">Sub-Sub Menu</a></li>
# 			  <li><a href="#">Sub-Sub Menu</a></li>
# 			  <li><a href="#">Sub-Sub Menu</a></li>
#
# 			  <li><h5>Sub-Sub Menu</h5>
# 				  <ul>
# 					  <li><a href="#">Sub-Sub-Sub Menu</a></li>
# 					  <li><a href="#">Sub-Sub-Sub Menu</a></li>
# 					  <li><a href="#">Sub-Sub-Sub Menu</a></li>
# 					  <li><h6>Sub-Sub-Sub Menu</h6>
# 				  		<ul>
# 						  <li><a href="#">Sub-Sub-Sub-Sub Menu</a></li>
# 						  <li><a href="#">Sub-Sub-Sub-Sub Menu</a></li>
# 						  <li><a href="#">Sub-Sub-Sub-Sub Menu</a></li>
# 					  	</ul>
# 		  	  		   </li>
# 				  </ul>
# 		  	  </li>
# 		  </ul>
# 	  </li>
#     </ul>
#   </li>
# </ul>
# -->
#     </div>
#     <a id="content" name="content">
#     </a>
#     <div id="contain_column2">
#      <!-- InstanceBeginEditable name="Content_Column2" -->
#      <h1>
#       Faculty and Areas of Research
#      </h1>
#      <p>
#       The following is a brief description of research programs of full-time faculty in the Department of Biological Sciences, and the institution that awarded their doctorate degree.
#      </p>
#      <h2>
#       Faculty available to serve as undergraduate &amp; thesis advisors:
#      </h2>
#      <p>
#       <strong>
#        Bengt J. Allen, Ph.D.
#       </strong>
#       (State University of New York, Stony Brook).
#       <span class="grygreen">
#        Marine Community Ecology.
#       </span>
#       Effects of climate change on the structure and function of rocky shore communities. Interactions between native seagrass and an invasive marine bivalve.
#       <a href="mailto:bengt.allen@csulb.edu">
#        bengt.allen@csulb.edu
#       </a>
#       (
#       <a class="link2" href="http://web.csulb.edu/%7ebjallen/Site/Home.html">
#        home page
#       </a>
#       )
#      </p>
#      <p>
#       <strong>
#        James W. Archie, Ph.D.
#       </strong>
#       (State University of New York, Stony Brook).
#       <span class="grygreen">
#        Evolutionary and Ecological Genetics; Population Biology; Biostatistics.
#       </span>
#       Evolutionary and ecological genetics of lizards in the genus
#       <cite>
#        Sceloporus.
#       </cite>
#       Phylogeography of
#       <cite>
#        S. occidentalis
#       </cite>
#       and
#       <cite>
#        S. graciosus.
#       </cite>
#       Evolutionary significance of mtDNA clade boundaries.
#       <a href="mailto: james.archie@csulb.edu">
#        james.archie@csulb.edu
#       </a>
#      </p>
#      <p>
#       <strong>
#        Flora Banuett, Ph.D.
#       </strong>
#       (University of Oregon).
#       <span class="grygreen">
#        Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus
#        <cite>
#         Ustilago maydis.
#        </cite>
#       </span>
#       Signal transduction and plant-pathogen interactions. Genetic determinants of the life cycle  the mating types.
#       <a href="mailto:flora.banuett@csulb.edu">
#        flora.banuett@csulb.edu
#       </a>
#      </p>
#      <p>
#       <strong>
#        Renaud Berlemont, Ph.D.
#       </strong>
#       (University of Liege, Belgium). Microbial genomics and bioinformatics. Comparative (meta)genomics and polysaccharides processing by environmental microbial isolates/communities (e.g. cellulose degredation).
#       <a href="mailto:renaud.berlemont@csulb.edu">
#        renaud.berlemont@csulb.edu
#       </a>
#       <a href="https://csulb.academia.edu/RenaudBerlemont">
#        Lab Website
#       </a>
#      </p>
#      <p>
#       <strong>
#        Judy A. Brusslan, Ph.D.
#       </strong>
#       (University of Chicago).
#       <span class="grygreen">
#        Plant molecular biology.
#       </span>
#       Leaf senescence in
#       <i>
#        Arabidopsis thaliana.
#       </i>
#       Genetic and genome-wide analysis of histone modifications that accompany leaf senescence.
#       <a href="mailto:judy.bruss@csulb.edu">
#        judy.brusslan@csulb.edu;
#       </a>
#       <a href="http://web.csulb.edu/~bruss/">
#        Lab Website
#       </a>
#      </p>
#      <p>
#       <b>
#        Ashley Carter, Ph.D.
#       </b>
#       (Yale University).
#       <span class="grygreen">
#        Theoretical and empirical evolutionary biology.
#       </span>
#       Theoretical: mathematical and computer simulation models of evolutionary processes, comparative allometric studies.  Empirical: insect quantitative genetics and morphometrics, fluctuating asymmetry.
#       <a href="mailto:ashley.carter@csulb.edu">
#        ashley.carter@csulb.edu
#       </a>
#       <a href="http://web.csulb.edu/%7eacarter3/index.html">
#        Lab Website
#       </a>
#      </p>
#      <p>
#       <strong>
#        Jesse Dillon, Ph.D.
#       </strong>
#       (University of Oregon).
#       <span class="grygreen">
#        Microbial ecology and evolution.
#       </span>
#       Molecular diversity and ecophysiology of microbial communities in extreme environments.
#       <a href="mailto:jesse.dillon@csulb.edu">
#        jesse.dillon@csulb.edu;
#       </a>
#       <a href="http://web.csulb.edu/~jdillon/">
#        Lab website
#       </a>
#      </p>
#      <p>
#       <strong>
#        Elizabeth D. Eldon, Ph.D
#       </strong>
#       . (Indiana University, Bloomington). Developmental biology. Genetic and molecular analysis of receptor signaling in development and innate immunity.
#       <a href="mailto:e.eldon@csulb.edu">
#        e.eldon@csulb.edu
#       </a>
#      </p>
#      <p>
#       <strong>
#        Amanda E. Fisher, Ph.D.
#       </strong>
#       (Idaho State University)
#       <stong>
#       </stong>
#      </p>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# Plant evolution and systematics, especially Acanthaceae and Poaceae. Floristics and plant conservation.
# <a href="mailto:Amanda.Fisher@csulb.edu">
#  amanda.fisher@csulb.edu
# </a>
# <p>
#  <strong>
#   Deborah A. Fraser Ph.D.
#  </strong>
#  (University of Wales, Cardiff)
#  <strong>
#  </strong>
#  Investigating molecular mechanisms of the innate immune response. We are looking at the role of complement proteins in inflammatory diseases such as atherosclerosis, to identify novel therapeutic targets.
#  <a href="mailto:deborah.fraser@csulb.edu">
#   deborah.fraser@csulb.edu
#  </a>
# </p>
# <p>
#  <strong>
#   Editte Gharakhanian, Ph.D.
#  </strong>
#  (University of California, Los Angeles).
#  <span class="grygreen">
#   Molecular cell biology.
#  </span>
#  Identify genes and gene products involved in trafficking of proteins to the lysosome of Baker’s yeast; study their conservation in humans and their connection to human diseases such as Alzheimer’s and cancer.
#  <a href="mailto:e.ghara@csulb.edu">
#   e.ghara@csulb.edu.
#  </a>
#  <a href="http://web.csulb.edu/labs/GharakhanianLab/">
#   Lab Website.
#  </a>
# </p>
# <p>
#  <strong>
#   Michael Harris, Ph.D.
#  </strong>
#  (University of British Columbia ).
#  <span class="grygreen">
#   Physiology.
#  </span>
#  Our research is primarily focused around questions of how the body sets and meets the demands of metabolism. Studies of metabolic regulation, and of the cells and neuronal circuits that respond to CO2 and O2 and modulate breathing and blood flow. Also, the evolutionary origins and consistency of these mechanisms across species from invertebrates to mammals.
#  <a href="mailto:michael.harris2@csulb.edu">
#   michael.harris2@csulb.edu.
#  </a>
#  <p>
#   <strong>
#    Erika Holland, Ph.D.
#   </strong>
#   (University of California, Davis).
#   <span class="grygreen">
#    Aquatic Toxicology.
#   </span>
#   My aim is to understand the impact of pollutants on aquatic organisms, particularly fish. Ongoing research focuses on chemicals that alter Ca2+ signaling pathways essential physiological processes including neurodevelopment, striated muscle function and oocyte fertilization.
#   <a href="mailto:erika.holland@csulb.edu">
#    erika.holland@csulb.edu.
#   </a>
#   <p>
#    <strong>
#     Darren Johnson, Ph.D.
#    </strong>
#    (Oregon State University).
#    <span class="grygreen">
#     Ecology and evolutionary biology of reef fishes.
#    </span>
#    .  Field studies of demographic rates and population dynamics.  Quantitative genetics of growth and behavior.  Natural selection in the sea.
#    <a href="mailto:Darren.Johnson@csulb.edu">
#     Darren.Johnson@csulb.edu
#    </a>
#    ,
#    <a href="http://darrenwjohnson.weebly.com">
#     Lab website
#    </a>
#    <br/>
#   </p>
#   <p>
#    <strong>
#     Sandy Kawano, Ph.D.
#    </strong>
#    (Clemson University).
#    <span class="grygreen">
#     Comparative physiology, biomechanics, and morphology of vertebrates.
#    </span>
#    My research broadly addresses the origins and maintenance of phenotypic diversity by examining how musculoskeletal design drives the performance of fitness-related traits in different environments. Research questions often relate to the locomotion of fishes and amphibians (extinct or extant) across water and land, but are also open to other systems
#    <a href="mailto:sandy.kawano@csulb.edu">
#     sandy.kawano@csulb.edu
#    </a>
#   </p>
#   <p>
#    <strong>
#     Balwant S. Khatra, Ph.D.
#    </strong>
#    (University of Leeds, England).
#    <span class="grygreen">
#     Metabolic regulation.
#    </span>
#    Hormonal regulation of cellular metabolism.
#    <a href="mailto:balwant.khatra@csulb.edu">
#     balwant.khatra@csulb.edu
#    </a>
#   </p>
#   <p>
#    <strong>
#     Lisa S. Klig, Ph.D.
#    </strong>
#    (Albert Einstein College of Medicine).
#    <span class="grygreen">
#     Molecular genetics and bioinformatics.
#    </span>
#    Analysis of inositol metabolism in the model organism
#    <i>
#     Drosophila melanogaster.
#    </i>
#    Inositol is a sugar that can serve as a precursor for a membrane phospholipid (phosphatidylinositol), a second messenger in signal transduction, an osmolyte, or an energy source. Disruption of inositol metabolism has been observed in patients with bipolar disease, developmental disorders, and diabetes. Inositol metabolism may also be involved in the pathogenicity of specific fungi that infect humans. Furthering the understanding of inositol metabolism may lead to effective therapeutic agents.
#    <a href="mailto:ls.klig@csulb.edu">
#     ls.klig@csulb.edu
#    </a>
#   </p>
#   <p>
#    <strong>
#     Kay Lee-Fruman, Ph.D.
#    </strong>
#    (Harvard University).
#    <span class="grygreen">
#     Cancer cell biology/immunology.
#    </span>
#    Molecular mechanism of immunosuppressant and anti-cancer drugs. We study the signal transduction pathways regulating cell growth and proliferation, with an emphasis on kinase enzymes.
#    <a href="mailto:kay.lee-fruman@csulb.edu">
#     kay.lee-fruman@csulb.edu
#    </a>
#   </p>
#   <p>
#    <strong>
#     Brian Livingston, Ph.D.
#    </strong>
#    (UC Santa Barbara)
#    <span class="grygreen">
#     <span>
#      Development and Evolution.
#     </span>
#    </span>
#    <span>
#     We study the development and evolution of mineralized tissue in echinoderms. We use proteomics and genomics to identify genes that encode proteins involved in forming a skeleton. We use molecular techniques to study expression of these genes and to study how they evolve.
#     <a href="mailto:brian.livingston@csulb.edu">
#      brian.livingston@csulb.edu
#     </a>
#     .
#     <a href="http://web.csulb.edu/~blivings/">
#      Lab Website.
#     </a>
#     <br/>
#     <strong>
#     </strong>
#    </span>
#   </p>
#   <p>
#    <strong>
#     Christopher G. Lowe, Ph.D.
#    </strong>
#    (University of Hawaii, Manoa).
#    <span class="grygreen">
#     Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.
#    </span>
#    Emphasis on bioenergetics, physiological and behavioral fisheries ecology, and movement patterns of gamefishes and elasmobranches.
#    <a href="mailto:chris.lowe@csulb.edu">
#     chris.lowe@csulb.edu;
#    </a>
#    <a href="http://www.csulb.edu/shark-lab">
#     SharkLab website
#    </a>
#   </p>
#   <p>
#    <strong>
#    </strong>
#    <span class="grygreen">
#    </span>
#    <a href="">
#    </a>
#    <a href="">
#    </a>
#   </p>
#   <p>
#    <strong>
#     Douglas Pace, Ph.D.
#    </strong>
#    <span class="grygreen">
#     Ecological Physiology.
#    </span>
#    Physiological mechanisms of adaptation. Elucidation of the molecular and biochemical pathways that allow organisms to tolerate environmental stress and variability. Laboratory focuses on cellular physiology through investigations of the parasitic protozoan
#    <i>
#     Toxoplasma gondii
#    </i>
#    and organismal physiology through research on marine invertebrate larvae.
#    <a href="mailto:Douglas.Pace@csulb.edu">
#     Douglas.Pace@csulb.edu,
#    </a>
#   </p>
#  </p>
# </p>
# <a href="https://sites.google.com/site/ecophysiologylab/home">
#  Lab Website
# </a>
# <p>
#  <strong>
#   Bruno Pernet, Ph.D.
#  </strong>
#  (University of Washington, Seattle)
#  <span class="grygreen">
#   . Marine invertebrate biology.
#  </span>
#  Development, functional morphology, and evolution of marine invertebrate larvae.
#  <a href="mailto:bruno.pernet@csulb.edu">
#   bruno.pernet@csulb.edu;
#  </a>
#  <a href="http://web.csulb.edu/~bpernet">
#   Lab website
#  </a>
# </p>
# <p>
#  <strong>
#   Bryan Rourke, Ph.D.
#  </strong>
#  (University of California, Irvine).
#  <span class="grygreen">
#   Integrative animal physiology.
#  </span>
#  Vertebrate muscle physiology, effects of hibernation, exercise, and metabolism.
#  <a href="mailto:bryan.rourke@csulb.edu">
#   bryan.rourke@csulb.edu;
#  </a>
#  <a href="http://web.csulb.edu/~brourke">
#   Lab website
#  </a>
# </p>
# <p>
#  <strong>
#   Kevin Sinchak, Ph.D.
#  </strong>
#  (Michigan State University)
#  <span class="grygreen">
#   Reproductive behavioral neuroendocrinology; neuroscience and neurosteroids.
#  </span>
#  I study the gonadal steroid regulation of neural circuits that control reproductive behavior, and the physiology and function of steroids made in the brain (neurosteroids).
#  <a href="mailto:kevin.sinchak@csulb.edu">
#   kevin.sinchak@csulb.edu
#  </a>
# </p>
# <p>
#  <strong>
#   Ted Stankowich, Ph.D.
#  </strong>
#  (University of California, Davis)
#  <span class="grygreen">
#   Evolutionary Behavioral Ecology.
#  </span>
#  Evolution of predator-prey interactions, including antipredator behavior, defensive weaponry, predator recognition, coloration, risk assessment, and escape decisions.  Main focus is on mammals but enjoys working on other taxa as well.
#  <a href="mailto:Theodore.Stankowich@csulb.edu">
#   Theodore.Stankowich@csulb.edu
#  </a>
#  <a href="http://web.csulb.edu/~tstankow/">
#   Lab website
#  </a>
# </p>
# <p>
#  <strong>
#   Houng-Wei Tsai, Ph.D.
#  </strong>
#  (University of Kentucky)
#  <strong>
#  </strong>
#  <span class="grygreen">
#   Epigenetic neuroendocrinology.
#  </span>
#  My research interest is to understand the neuroendocrine mechanisms that regulate reproductive function and behaviors at molecular, cellular, and systemic levels. I use epigenetic approach to identify the sexually dimorphic genes that control sexual differentiation in the mouse brain structure and behavior.
#  <a href="mailto:houng-wei.tsai@csulb.edu">
#   houng-wei.tsai@csulb.edu
#  </a>
#  <a href="http://csulb.edu/%7ehtsai/index.html">
#   Lab website
#  </a>
# </p>
# <p>
#  <strong>
#   Dessie L. Underwood, Ph.D.
#  </strong>
#  (University of California, Davis).
#  <span class="grygreen">
#   Insect biology.
#  </span>
#  Insect behavioral ecology; plant-insect interactions; the evolution of cooperation, division of labor, and sex ratio; lepidopteran cytogenetics; chromosomal non-disjunction.
#  <a href="mailto:dessie.underwood@csulb.edu">
#   dlunderw@csulb.edu,
#  </a>
#  <a href="http://streamecologyassessmentlab.weebly.com/">
#   Research page
#  </a>
# </p>
# <p>
#  <strong>
#   Christine Whitcraft, Ph.D.
#  </strong>
#  UCSD - Scripps Institution of Oceanography.
#  <span class="grygreen">
#   Wetlands Ecology.
#  </span>
#  Conservation Biology, Human Impacts on Salt Marsh Ecosystems &amp; Food Webs.
#  <a href="mailto:christine.whitcraft@csulb.edu">
#   christine.whitcraft@csulb.edu;
#  </a>
#  <a href="http://web.csulb.edu/~cwhitcra/">
#   Lab website
#  </a>
# </p>
# <p>
#  <strong>
#   Raymond R. Wilson, Ph.D.
#  </strong>
#  (University of California, San Diego-Scripps Institution of Oceanography).
#  <span class="grygreen">
#   Marine ichthyology.
#  </span>
#  Population genetics of marine fishes.
#  <a href="mailto:ray.wilson@csulb.edu">
#   ray.wilson@csulb.edu
#  </a>
# </p>
# <p>
#  <strong>
#   Kelly Young, Ph.D.
#  </strong>
#  (John Hopkins School of Public Health, Baltimore, MD).
#  <span class="grygreen">
#   Reproductive biologist.
#  </span>
#  Seasonal changes in reproductive physiology; photoperiodic regulation of ovarian/testicular function.
#  <a href="mailto:kelly.young@csulb.edu">
#   kelly.young@csulb.edu
#  </a>
# </p>
# <p>
#  <strong>
#   Mason X. Zhang, Ph.D.
#  </strong>
#  (University of Wisconsin, Madison).
#  <span class="grygreen">
#   Host-pathogen interactions.
#  </span>
#  Genetic engineering of human antibodies; host defense mechanisms against microbial infection.
#  <a href="mailto:mason.zhang@csulb.edu">
#   mason.zhang@csulb.edu
#  </a>
# </p>
# <!-- InstanceEndEditable -->
# <div id="contain_column3">
#  <!-- InstanceBeginEditable name="Content_Column3" -->
#  <!-- InstanceEndEditable -->
# </div>
# <div class="clear_float">
# </div>
# <div id="footer">
#  <div id="contain_footer">
#   [an error occurred while processing this directive]
#   <div id="contain_address">
#    <div id="address_content">
#     <address>
#      California State University, Long Beach
#      <br/>
#      1250 Bellflower Boulevard, Long Beach, California 90840
#     </address>
#    </div>
#   </div>
#   <div id="contain_utilities">
#    <ul>
#     <!--<li><a href="/policy/">Privacy Policy</a></li> -->
#     <li>
#      <a href="/about/website/">
#       Website Credits
#      </a>
#     </li>
#     <li>
#      <a href="/feedback/">
#       Feedback
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="clear_float">
#   </div>
#  </div>
# </div>
# <!-- InstanceEnd -->

# %%
soup.find_all('p')
# Out:
# [<p>The following is a brief description of research programs of full-time faculty in the Department of Biological Sciences, and the institution that awarded their doctorate degree.</p>,
#  <p><strong>Bengt J. Allen, Ph.D.</strong> (State University of New York, Stony Brook).  <span class="grygreen">Marine Community Ecology. </span>Effects of climate change on the structure and function of rocky shore communities. Interactions between native seagrass and an invasive marine bivalve.<a href="mailto:bengt.allen@csulb.edu">bengt.allen@csulb.edu</a> (<a class="link2" href="http://web.csulb.edu/%7ebjallen/Site/Home.html">home page</a>)</p>,
#  <p><strong>James W. Archie, Ph.D.</strong> (State University of New York, Stony Brook). <span class="grygreen">Evolutionary and Ecological Genetics; Population Biology; Biostatistics. </span>Evolutionary and ecological genetics of lizards in the genus <cite>Sceloporus.</cite>  Phylogeography of <cite>S. occidentalis </cite>and  <cite>S. graciosus.</cite> Evolutionary significance of mtDNA clade boundaries. <a href="mailto: james.archie@csulb.edu">james.archie@csulb.edu</a></p>,
#  <p><strong>Flora Banuett, Ph.D.</strong> (University of Oregon).<span class="grygreen"> Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus <cite>Ustilago maydis.</cite></span> Signal transduction and plant-pathogen interactions. Genetic determinants of the life cycle  the mating types. <a href="mailto:flora.banuett@csulb.edu">flora.banuett@csulb.edu</a></p>,
#  <p><strong>Renaud Berlemont, Ph.D.</strong> (University of Liege, Belgium). Microbial genomics and bioinformatics. Comparative (meta)genomics and polysaccharides processing by environmental microbial isolates/communities (e.g. cellulose degredation). <a href="mailto:renaud.berlemont@csulb.edu">renaud.berlemont@csulb.edu</a> <a href="https://csulb.academia.edu/RenaudBerlemont">Lab Website</a></p>,
#  <p><strong>Judy A. Brusslan, Ph.D. </strong>(University of Chicago). <span class="grygreen">Plant molecular biology.</span> Leaf senescence in <i>Arabidopsis thaliana.</i>Genetic and genome-wide analysis of histone modifications that accompany leaf senescence. <a href="mailto:judy.bruss@csulb.edu">judy.brusslan@csulb.edu;</a> <a href="http://web.csulb.edu/~bruss/">Lab Website</a></p>,
#  <p><b>Ashley Carter, Ph.D.  </b>(Yale University).  <span class="grygreen">Theoretical and empirical evolutionary biology. </span> Theoretical: mathematical and computer simulation models of evolutionary processes, comparative allometric studies.  Empirical: insect quantitative genetics and morphometrics, fluctuating asymmetry.  <a href="mailto:ashley.carter@csulb.edu">ashley.carter@csulb.edu</a> <a href="http://web.csulb.edu/%7eacarter3/index.html">Lab Website</a></p>,
#  <p><strong>Jesse Dillon, Ph.D. </strong>(University of Oregon). <span class="grygreen">Microbial ecology and evolution. </span>Molecular diversity and ecophysiology of microbial communities in extreme environments. <a href="mailto:jesse.dillon@csulb.edu">jesse.dillon@csulb.edu;</a> <a href="http://web.csulb.edu/~jdillon/">Lab website</a></p>,
#  <p><strong>Elizabeth D. Eldon, Ph.D</strong>. (Indiana University, Bloomington). Developmental biology. Genetic and molecular analysis of receptor signaling in development and innate immunity.<a href="mailto:e.eldon@csulb.edu"> e.eldon@csulb.edu</a></p>,
#  <p><strong>Amanda E. Fisher, Ph.D.</strong>(Idaho State University)<stong></stong></p>,
#  <p><strong>Deborah A. Fraser Ph.D. </strong>(University of Wales, Cardiff)<strong> </strong>Investigating molecular mechanisms of the innate immune response. We are looking at the role of complement proteins in inflammatory diseases such as atherosclerosis, to identify novel therapeutic targets. <a href="mailto:deborah.fraser@csulb.edu">deborah.fraser@csulb.edu</a></p>,
#  <p><strong>Editte Gharakhanian, Ph.D.</strong> (University of California, Los Angeles). <span class="grygreen">Molecular cell biology.</span> Identify genes and gene products involved in trafficking of proteins to the lysosome of Baker’s yeast; study their conservation in humans and their connection to human diseases such as Alzheimer’s and cancer. <a href="mailto:e.ghara@csulb.edu">e.ghara@csulb.edu.</a> <a href="http://web.csulb.edu/labs/GharakhanianLab/">Lab Website.</a></p>,
#  <p><strong>Michael Harris, Ph.D.</strong> (University of British Columbia ). <span class="grygreen">Physiology.</span> Our research is primarily focused around questions of how the body sets and meets the demands of metabolism. Studies of metabolic regulation, and of the cells and neuronal circuits that respond to CO2 and O2 and modulate breathing and blood flow. Also, the evolutionary origins and consistency of these mechanisms across species from invertebrates to mammals. <a href="mailto:michael.harris2@csulb.edu">michael.harris2@csulb.edu.</a>
#  <p><strong>Erika Holland, Ph.D.</strong> (University of California, Davis). <span class="grygreen">Aquatic Toxicology.</span> My aim is to understand the impact of pollutants on aquatic organisms, particularly fish. Ongoing research focuses on chemicals that alter Ca2+ signaling pathways essential physiological processes including neurodevelopment, striated muscle function and oocyte fertilization. <a href="mailto:erika.holland@csulb.edu">erika.holland@csulb.edu.</a>
#  <p><strong>Darren Johnson, Ph.D.</strong> (Oregon State University).<span class="grygreen"> Ecology and evolutionary biology of reef fishes.  </span>.  Field studies of demographic rates and population dynamics.  Quantitative genetics of growth and behavior.  Natural selection in the sea.  <a href="mailto:Darren.Johnson@csulb.edu"> Darren.Johnson@csulb.edu</a>, <a href="http://darrenwjohnson.weebly.com">Lab website</a><br/>
#  </p>
#  <p><strong>Sandy Kawano, Ph.D. </strong>(Clemson University). <span class="grygreen">Comparative physiology, biomechanics, and morphology of vertebrates.</span> My research broadly addresses the origins and maintenance of phenotypic diversity by examining how musculoskeletal design drives the performance of fitness-related traits in different environments. Research questions often relate to the locomotion of fishes and amphibians (extinct or extant) across water and land, but are also open to other systems  <a href="mailto:sandy.kawano@csulb.edu">sandy.kawano@csulb.edu</a></p>
#  <p><strong>Balwant S. Khatra, Ph.D.</strong> (University of Leeds, England). <span class="grygreen">Metabolic regulation.</span> Hormonal regulation of cellular metabolism. <a href="mailto:balwant.khatra@csulb.edu">balwant.khatra@csulb.edu</a></p>
#  <p><strong>Lisa S. Klig, Ph.D. </strong>(Albert Einstein College of Medicine). <span class="grygreen">Molecular genetics and bioinformatics.</span>Analysis of inositol metabolism in the model organism <i>Drosophila melanogaster.</i> Inositol is a sugar that can serve as a precursor for a membrane phospholipid (phosphatidylinositol), a second messenger in signal transduction, an osmolyte, or an energy source. Disruption of inositol metabolism has been observed in patients with bipolar disease, developmental disorders, and diabetes. Inositol metabolism may also be involved in the pathogenicity of specific fungi that infect humans. Furthering the understanding of inositol metabolism may lead to effective therapeutic agents.  <a href="mailto:ls.klig@csulb.edu">ls.klig@csulb.edu</a></p>
#  <p><strong>Kay Lee-Fruman, Ph.D.</strong> (Harvard University).<span class="grygreen"> Cancer cell biology/immunology.</span> Molecular mechanism of immunosuppressant and anti-cancer drugs. We study the signal transduction pathways regulating cell growth and proliferation, with an emphasis on kinase enzymes. <a href="mailto:kay.lee-fruman@csulb.edu">kay.lee-fruman@csulb.edu</a> </p>
#  <p><strong>Brian Livingston, Ph.D. </strong>(UC Santa Barbara)<span class="grygreen"> <span>Development and Evolution.</span></span><span> We study the development and evolution of mineralized tissue in echinoderms. We use proteomics and genomics to identify genes that encode proteins involved in forming a skeleton. We use molecular techniques to study expression of these genes and to study how they evolve. <a href="mailto:brian.livingston@csulb.edu">brian.livingston@csulb.edu</a>.<a href="http://web.csulb.edu/~blivings/"> Lab Website.</a><br/>
#  <strong></strong></span></p>
#  <p><strong>Christopher G. Lowe, Ph.D.</strong> (University of Hawaii, Manoa). <span class="grygreen">Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.</span> Emphasis on bioenergetics, physiological and behavioral fisheries ecology, and movement patterns of gamefishes and elasmobranches. <a href="mailto:chris.lowe@csulb.edu">chris.lowe@csulb.edu;</a> <a href="http://www.csulb.edu/shark-lab">SharkLab website</a></p>
#  <p><strong></strong><span class="grygreen"> </span> <a href=""></a> <a href=""></a></p>
#  <p><strong>Douglas Pace, Ph.D. </strong><span class="grygreen"> Ecological Physiology.</span>Physiological mechanisms of adaptation. Elucidation of the molecular and biochemical pathways that allow organisms to tolerate environmental stress and variability. Laboratory focuses on cellular physiology through investigations of the parasitic protozoan <i>Toxoplasma gondii</i> and organismal physiology through research on marine invertebrate larvae.  <a href="mailto:Douglas.Pace@csulb.edu">Douglas.Pace@csulb.edu,  </a></p></p></p>,
#  <p><strong>Erika Holland, Ph.D.</strong> (University of California, Davis). <span class="grygreen">Aquatic Toxicology.</span> My aim is to understand the impact of pollutants on aquatic organisms, particularly fish. Ongoing research focuses on chemicals that alter Ca2+ signaling pathways essential physiological processes including neurodevelopment, striated muscle function and oocyte fertilization. <a href="mailto:erika.holland@csulb.edu">erika.holland@csulb.edu.</a>
#  <p><strong>Darren Johnson, Ph.D.</strong> (Oregon State University).<span class="grygreen"> Ecology and evolutionary biology of reef fishes.  </span>.  Field studies of demographic rates and population dynamics.  Quantitative genetics of growth and behavior.  Natural selection in the sea.  <a href="mailto:Darren.Johnson@csulb.edu"> Darren.Johnson@csulb.edu</a>, <a href="http://darrenwjohnson.weebly.com">Lab website</a><br/>
#  </p>
#  <p><strong>Sandy Kawano, Ph.D. </strong>(Clemson University). <span class="grygreen">Comparative physiology, biomechanics, and morphology of vertebrates.</span> My research broadly addresses the origins and maintenance of phenotypic diversity by examining how musculoskeletal design drives the performance of fitness-related traits in different environments. Research questions often relate to the locomotion of fishes and amphibians (extinct or extant) across water and land, but are also open to other systems  <a href="mailto:sandy.kawano@csulb.edu">sandy.kawano@csulb.edu</a></p>
#  <p><strong>Balwant S. Khatra, Ph.D.</strong> (University of Leeds, England). <span class="grygreen">Metabolic regulation.</span> Hormonal regulation of cellular metabolism. <a href="mailto:balwant.khatra@csulb.edu">balwant.khatra@csulb.edu</a></p>
#  <p><strong>Lisa S. Klig, Ph.D. </strong>(Albert Einstein College of Medicine). <span class="grygreen">Molecular genetics and bioinformatics.</span>Analysis of inositol metabolism in the model organism <i>Drosophila melanogaster.</i> Inositol is a sugar that can serve as a precursor for a membrane phospholipid (phosphatidylinositol), a second messenger in signal transduction, an osmolyte, or an energy source. Disruption of inositol metabolism has been observed in patients with bipolar disease, developmental disorders, and diabetes. Inositol metabolism may also be involved in the pathogenicity of specific fungi that infect humans. Furthering the understanding of inositol metabolism may lead to effective therapeutic agents.  <a href="mailto:ls.klig@csulb.edu">ls.klig@csulb.edu</a></p>
#  <p><strong>Kay Lee-Fruman, Ph.D.</strong> (Harvard University).<span class="grygreen"> Cancer cell biology/immunology.</span> Molecular mechanism of immunosuppressant and anti-cancer drugs. We study the signal transduction pathways regulating cell growth and proliferation, with an emphasis on kinase enzymes. <a href="mailto:kay.lee-fruman@csulb.edu">kay.lee-fruman@csulb.edu</a> </p>
#  <p><strong>Brian Livingston, Ph.D. </strong>(UC Santa Barbara)<span class="grygreen"> <span>Development and Evolution.</span></span><span> We study the development and evolution of mineralized tissue in echinoderms. We use proteomics and genomics to identify genes that encode proteins involved in forming a skeleton. We use molecular techniques to study expression of these genes and to study how they evolve. <a href="mailto:brian.livingston@csulb.edu">brian.livingston@csulb.edu</a>.<a href="http://web.csulb.edu/~blivings/"> Lab Website.</a><br/>
#  <strong></strong></span></p>
#  <p><strong>Christopher G. Lowe, Ph.D.</strong> (University of Hawaii, Manoa). <span class="grygreen">Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.</span> Emphasis on bioenergetics, physiological and behavioral fisheries ecology, and movement patterns of gamefishes and elasmobranches. <a href="mailto:chris.lowe@csulb.edu">chris.lowe@csulb.edu;</a> <a href="http://www.csulb.edu/shark-lab">SharkLab website</a></p>
#  <p><strong></strong><span class="grygreen"> </span> <a href=""></a> <a href=""></a></p>
#  <p><strong>Douglas Pace, Ph.D. </strong><span class="grygreen"> Ecological Physiology.</span>Physiological mechanisms of adaptation. Elucidation of the molecular and biochemical pathways that allow organisms to tolerate environmental stress and variability. Laboratory focuses on cellular physiology through investigations of the parasitic protozoan <i>Toxoplasma gondii</i> and organismal physiology through research on marine invertebrate larvae.  <a href="mailto:Douglas.Pace@csulb.edu">Douglas.Pace@csulb.edu,  </a></p></p>,
#  <p><strong>Darren Johnson, Ph.D.</strong> (Oregon State University).<span class="grygreen"> Ecology and evolutionary biology of reef fishes.  </span>.  Field studies of demographic rates and population dynamics.  Quantitative genetics of growth and behavior.  Natural selection in the sea.  <a href="mailto:Darren.Johnson@csulb.edu"> Darren.Johnson@csulb.edu</a>, <a href="http://darrenwjohnson.weebly.com">Lab website</a><br/>
#  </p>,
#  <p><strong>Sandy Kawano, Ph.D. </strong>(Clemson University). <span class="grygreen">Comparative physiology, biomechanics, and morphology of vertebrates.</span> My research broadly addresses the origins and maintenance of phenotypic diversity by examining how musculoskeletal design drives the performance of fitness-related traits in different environments. Research questions often relate to the locomotion of fishes and amphibians (extinct or extant) across water and land, but are also open to other systems  <a href="mailto:sandy.kawano@csulb.edu">sandy.kawano@csulb.edu</a></p>,
#  <p><strong>Balwant S. Khatra, Ph.D.</strong> (University of Leeds, England). <span class="grygreen">Metabolic regulation.</span> Hormonal regulation of cellular metabolism. <a href="mailto:balwant.khatra@csulb.edu">balwant.khatra@csulb.edu</a></p>,
#  <p><strong>Lisa S. Klig, Ph.D. </strong>(Albert Einstein College of Medicine). <span class="grygreen">Molecular genetics and bioinformatics.</span>Analysis of inositol metabolism in the model organism <i>Drosophila melanogaster.</i> Inositol is a sugar that can serve as a precursor for a membrane phospholipid (phosphatidylinositol), a second messenger in signal transduction, an osmolyte, or an energy source. Disruption of inositol metabolism has been observed in patients with bipolar disease, developmental disorders, and diabetes. Inositol metabolism may also be involved in the pathogenicity of specific fungi that infect humans. Furthering the understanding of inositol metabolism may lead to effective therapeutic agents.  <a href="mailto:ls.klig@csulb.edu">ls.klig@csulb.edu</a></p>,
#  <p><strong>Kay Lee-Fruman, Ph.D.</strong> (Harvard University).<span class="grygreen"> Cancer cell biology/immunology.</span> Molecular mechanism of immunosuppressant and anti-cancer drugs. We study the signal transduction pathways regulating cell growth and proliferation, with an emphasis on kinase enzymes. <a href="mailto:kay.lee-fruman@csulb.edu">kay.lee-fruman@csulb.edu</a> </p>,
#  <p><strong>Brian Livingston, Ph.D. </strong>(UC Santa Barbara)<span class="grygreen"> <span>Development and Evolution.</span></span><span> We study the development and evolution of mineralized tissue in echinoderms. We use proteomics and genomics to identify genes that encode proteins involved in forming a skeleton. We use molecular techniques to study expression of these genes and to study how they evolve. <a href="mailto:brian.livingston@csulb.edu">brian.livingston@csulb.edu</a>.<a href="http://web.csulb.edu/~blivings/"> Lab Website.</a><br/>
#  <strong></strong></span></p>,
#  <p><strong>Christopher G. Lowe, Ph.D.</strong> (University of Hawaii, Manoa). <span class="grygreen">Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.</span> Emphasis on bioenergetics, physiological and behavioral fisheries ecology, and movement patterns of gamefishes and elasmobranches. <a href="mailto:chris.lowe@csulb.edu">chris.lowe@csulb.edu;</a> <a href="http://www.csulb.edu/shark-lab">SharkLab website</a></p>,
#  <p><strong></strong><span class="grygreen"> </span> <a href=""></a> <a href=""></a></p>,
#  <p><strong>Douglas Pace, Ph.D. </strong><span class="grygreen"> Ecological Physiology.</span>Physiological mechanisms of adaptation. Elucidation of the molecular and biochemical pathways that allow organisms to tolerate environmental stress and variability. Laboratory focuses on cellular physiology through investigations of the parasitic protozoan <i>Toxoplasma gondii</i> and organismal physiology through research on marine invertebrate larvae.  <a href="mailto:Douglas.Pace@csulb.edu">Douglas.Pace@csulb.edu,  </a></p>,
#  <p><strong>Bruno Pernet, Ph.D. </strong>(University of Washington, Seattle)<span class="grygreen">. Marine invertebrate biology.</span> Development, functional morphology, and evolution of marine invertebrate larvae. <a href="mailto:bruno.pernet@csulb.edu">bruno.pernet@csulb.edu;</a> <a href="http://web.csulb.edu/~bpernet">Lab website</a></p>,
#  <p><strong>Bryan Rourke, Ph.D.</strong> (University of California, Irvine). <span class="grygreen">Integrative animal physiology.</span> Vertebrate muscle physiology, effects of hibernation, exercise, and metabolism. <a href="mailto:bryan.rourke@csulb.edu">bryan.rourke@csulb.edu;</a> <a href="http://web.csulb.edu/~brourke">Lab website</a></p>,
#  <p><strong>Kevin Sinchak, Ph.D.</strong> (Michigan State University) <span class="grygreen">Reproductive behavioral neuroendocrinology; neuroscience and neurosteroids.</span> I study the gonadal steroid regulation of neural circuits that control reproductive behavior, and the physiology and function of steroids made in the brain (neurosteroids). <a href="mailto:kevin.sinchak@csulb.edu">kevin.sinchak@csulb.edu</a></p>,
#  <p><strong>Ted Stankowich, Ph.D.</strong> (University of California, Davis) <span class="grygreen">Evolutionary Behavioral Ecology.</span> Evolution of predator-prey interactions, including antipredator behavior, defensive weaponry, predator recognition, coloration, risk assessment, and escape decisions.  Main focus is on mammals but enjoys working on other taxa as well. <a href="mailto:Theodore.Stankowich@csulb.edu">Theodore.Stankowich@csulb.edu</a> <a href="http://web.csulb.edu/~tstankow/">Lab website</a></p>,
#  <p><strong>Houng-Wei Tsai, Ph.D. </strong>(University of Kentucky)<strong> </strong><span class="grygreen">Epigenetic neuroendocrinology. </span>My research interest is to understand the neuroendocrine mechanisms that regulate reproductive function and behaviors at molecular, cellular, and systemic levels. I use epigenetic approach to identify the sexually dimorphic genes that control sexual differentiation in the mouse brain structure and behavior. <a href="mailto:houng-wei.tsai@csulb.edu">houng-wei.tsai@csulb.edu </a><a href="http://csulb.edu/%7ehtsai/index.html">Lab website</a></p>,
#  <p><strong>Dessie L. Underwood, Ph.D.</strong> (University of California, Davis).<span class="grygreen"> Insect biology.</span> Insect behavioral ecology; plant-insect interactions; the evolution of cooperation, division of labor, and sex ratio; lepidopteran cytogenetics; chromosomal non-disjunction. <a href="mailto:dessie.underwood@csulb.edu">dlunderw@csulb.edu,</a> <a href="http://streamecologyassessmentlab.weebly.com/">Research page</a></p>,
#  <p><strong>Christine Whitcraft, Ph.D.</strong> UCSD - Scripps Institution of Oceanography. <span class="grygreen">Wetlands Ecology.</span> Conservation Biology, Human Impacts on Salt Marsh Ecosystems &amp; Food Webs. <a href="mailto:christine.whitcraft@csulb.edu">christine.whitcraft@csulb.edu;</a> <a href="http://web.csulb.edu/~cwhitcra/">Lab website</a></p>,
#  <p><strong>Raymond R. Wilson, Ph.D.</strong> (University of California, San Diego-Scripps Institution of Oceanography). <span class="grygreen">Marine ichthyology.</span> Population genetics of marine fishes. <a href="mailto:ray.wilson@csulb.edu">ray.wilson@csulb.edu</a></p>,
#  <p><strong>Kelly Young, Ph.D. </strong>(John Hopkins School of Public Health, Baltimore, MD). <span class="grygreen">Reproductive biologist.</span> Seasonal changes in reproductive physiology; photoperiodic regulation of ovarian/testicular function. <a href="mailto:kelly.young@csulb.edu">kelly.young@csulb.edu</a></p>,
#  <p><strong>Mason X. Zhang, Ph.D. </strong>(University of Wisconsin, Madison).<span class="grygreen"> Host-pathogen interactions.</span> Genetic engineering of human antibodies; host defense mechanisms against microbial infection. <a href="mailto:mason.zhang@csulb.edu">mason.zhang@csulb.edu</a></p>]

# %%
soup.find_all('p')[1]
# Out:
# <p><strong>Bengt J. Allen, Ph.D.</strong> (State University of New York, Stony Brook).  <span class="grygreen">Marine Community Ecology. </span>Effects of climate change on the structure and function of rocky shore communities. Interactions between native seagrass and an invasive marine bivalve.<a href="mailto:bengt.allen@csulb.edu">bengt.allen@csulb.edu</a> (<a class="link2" href="http://web.csulb.edu/%7ebjallen/Site/Home.html">home page</a>)</p>

# %%
list(soup.find_all('p')[1].children)
# Out:
# [<strong>Bengt J. Allen, Ph.D.</strong>,
#  ' (State University of New York, Stony Brook).  ',
#  <span class="grygreen">Marine Community Ecology. </span>,
#  'Effects of climate change on the structure and function of rocky shore communities. Interactions between native seagrass and an invasive marine bivalve.',
#  <a href="mailto:bengt.allen@csulb.edu">bengt.allen@csulb.edu</a>,
#  ' (',
#  <a class="link2" href="http://web.csulb.edu/%7ebjallen/Site/Home.html">home page</a>,
#  ')']

# %%
list(soup.find_all('p')[2].children)
# Out:
# [<strong>James W. Archie, Ph.D.</strong>,
#  ' (State University of New York, Stony Brook). ',
#  <span class="grygreen">Evolutionary and Ecological Genetics; Population Biology; Biostatistics. </span>,
#  'Evolutionary and ecological genetics of lizards in the genus ',
#  <cite>Sceloporus.</cite>,
#  '  Phylogeography of ',
#  <cite>S. occidentalis </cite>,
#  'and  ',
#  <cite>S. graciosus.</cite>,
#  ' Evolutionary significance of mtDNA clade boundaries. ',
#  <a href="mailto: james.archie@csulb.edu">james.archie@csulb.edu</a>]

# %%
list(soup.find_all('p')[3].children)
# Out:
# [<strong>Flora Banuett, Ph.D.</strong>,
#  ' (University of Oregon).',
#  <span class="grygreen"> Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus <cite>Ustilago maydis.</cite></span>,
#  ' Signal transduction and plant-pathogen interactions. Genetic determinants of the life cycle \x96 the mating types. ',
#  <a href="mailto:flora.banuett@csulb.edu">flora.banuett@csulb.edu</a>]

# %%
allen = soup.find_all('p')[1]
archie = soup.find_all('p')[2]
banuett = soup.find_all('p')[3]

print(allen.find('strong'))
print(archie.find('strong'))
print(banuett.find('strong'))
# Out:
# <strong>Bengt J. Allen, Ph.D.</strong>
# <strong>James W. Archie, Ph.D.</strong>
# <strong>Flora Banuett, Ph.D.</strong>

# %%
print(allen.find('span'))
print(archie.find('span'))
print(banuett.find('span'))
# Out:
# <span class="grygreen">Marine Community Ecology. </span>
# <span class="grygreen">Evolutionary and Ecological Genetics; Population Biology; Biostatistics. </span>
# <span class="grygreen"> Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus <cite>Ustilago maydis.</cite></span>

# %%
print(allen.find('a'))
print(archie.find('a'))
print(banuett.find('a'))
# Out:
# <a href="mailto:bengt.allen@csulb.edu">bengt.allen@csulb.edu</a>
# <a href="mailto: james.archie@csulb.edu">james.archie@csulb.edu</a>
# <a href="mailto:flora.banuett@csulb.edu">flora.banuett@csulb.edu</a>

# %%
print(allen.find_all('a')[1])
# Out:
# <a class="link2" href="http://web.csulb.edu/%7ebjallen/Site/Home.html">home page</a>

# %%
try:
    print(archie.find_all('a')[1])
except:
    print("No website, yo")
# Out:
# No website, yo

# %%
print(allen.find('strong').get_text())
# Out:
# Bengt J. Allen, Ph.D.

# %% [markdown]
# # Some more playing around

# %%
for item in soup.find_all('p')[1:]:
    try:
        print(item.find('strong').get_text())
    except:
        pass
    
    try:
        print(item.find('span').get_text())
    except:
        pass
    
    try:
        print(item.find('a').get_text())
    except:
        pass
    
    
    
    
    try:
        print(item.find_all('a')[1].get_text())
    except:
        print("No website, yo")
# Out:
# Bengt J. Allen, Ph.D.
# Marine Community Ecology.
# bengt.allen@csulb.edu
# home page
# James W. Archie, Ph.D.
# Evolutionary and Ecological Genetics; Population Biology; Biostatistics.
# james.archie@csulb.edu
# No website, yo
# Flora Banuett, Ph.D.
#  Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus Ustilago maydis.
# flora.banuett@csulb.edu
# No website, yo
# Renaud Berlemont, Ph.D.
# renaud.berlemont@csulb.edu
# Lab Website
# Judy A. Brusslan, Ph.D.
# Plant molecular biology.
# judy.brusslan@csulb.edu;
# Lab Website
# Theoretical and empirical evolutionary biology.
# ashley.carter@csulb.edu
# Lab Website
# Jesse Dillon, Ph.D.
# Microbial ecology and evolution.
# jesse.dillon@csulb.edu;
# Lab website
# Elizabeth D. Eldon, Ph.D
#  e.eldon@csulb.edu
# No website, yo
# Amanda E. Fisher, Ph.D.
# No website, yo
# Deborah A. Fraser Ph.D.
# deborah.fraser@csulb.edu
# No website, yo
# Editte Gharakhanian, Ph.D.
# Molecular cell biology.
# e.ghara@csulb.edu.
# Lab Website.
# Michael Harris, Ph.D.
# Physiology.
# michael.harris2@csulb.edu.
# erika.holland@csulb.edu.
# Erika Holland, Ph.D.
# Aquatic Toxicology.
# erika.holland@csulb.edu.
#  Darren.Johnson@csulb.edu
# Darren Johnson, Ph.D.
#  Ecology and evolutionary biology of reef fishes.
#  Darren.Johnson@csulb.edu
# Lab website
# Sandy Kawano, Ph.D.
# Comparative physiology, biomechanics, and morphology of vertebrates.
# sandy.kawano@csulb.edu
# No website, yo
# Balwant S. Khatra, Ph.D.
# Metabolic regulation.
# balwant.khatra@csulb.edu
# No website, yo
# Lisa S. Klig, Ph.D.
# Molecular genetics and bioinformatics.
# ls.klig@csulb.edu
# No website, yo
# Kay Lee-Fruman, Ph.D.
#  Cancer cell biology/immunology.
# kay.lee-fruman@csulb.edu
# No website, yo
# Brian Livingston, Ph.D.
#  Development and Evolution.
# brian.livingston@csulb.edu
#  Lab Website.
# Christopher G. Lowe, Ph.D.
# Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.
# chris.lowe@csulb.edu;
# SharkLab website
#
#
#
#
# Douglas Pace, Ph.D.
#  Ecological Physiology.
# Douglas.Pace@csulb.edu,
# No website, yo
# Bruno Pernet, Ph.D.
# . Marine invertebrate biology.
# bruno.pernet@csulb.edu;
# Lab website
# Bryan Rourke, Ph.D.
# Integrative animal physiology.
# bryan.rourke@csulb.edu;
# Lab website
# Kevin Sinchak, Ph.D.
# Reproductive behavioral neuroendocrinology; neuroscience and neurosteroids.
# kevin.sinchak@csulb.edu
# No website, yo
# Ted Stankowich, Ph.D.
# Evolutionary Behavioral Ecology.
# Theodore.Stankowich@csulb.edu
# Lab website
# Houng-Wei Tsai, Ph.D.
# Epigenetic neuroendocrinology.
# houng-wei.tsai@csulb.edu
# Lab website
# Dessie L. Underwood, Ph.D.
#  Insect biology.
# dlunderw@csulb.edu,
# Research page
# Christine Whitcraft, Ph.D.
# Wetlands Ecology.
# christine.whitcraft@csulb.edu;
# Lab website
# Raymond R. Wilson, Ph.D.
# Marine ichthyology.
# ray.wilson@csulb.edu
# No website, yo
# Kelly Young, Ph.D.
# Reproductive biologist.
# kelly.young@csulb.edu
# No website, yo
# Mason X. Zhang, Ph.D.
#  Host-pathogen interactions.
# mason.zhang@csulb.edu
# No website, yo

# %%
poup = BeautifulSoup('<META NAME="City" content="Austin">')
poup.find("meta", {"name":"City"})
poup.find("meta", {"name":"City"})['content']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 'Austin'

# %%
print(allen.find_all('a')[1].get("href"))
# Out:
# http://web.csulb.edu/%7ebjallen/Site/Home.html

# %%
for item in soup.find_all('p')[1:]:
    try:
        print(item.find('strong').get_text())
    except:
        pass
    
    try:
        print(item.find('span').get_text())
    except:
        pass
    
    try:
        print(item.find('a').get("href"))
    except:
        pass
    
    
    try:
        print(item.find_all('a')[1].get("href"))
    except:
        print("csulb.edu")
# Out:
# Bengt J. Allen, Ph.D.
# Marine Community Ecology.
# mailto:bengt.allen@csulb.edu
# http://web.csulb.edu/%7ebjallen/Site/Home.html
# James W. Archie, Ph.D.
# Evolutionary and Ecological Genetics; Population Biology; Biostatistics.
# mailto: james.archie@csulb.edu
# csulb.edu
# Flora Banuett, Ph.D.
#  Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus Ustilago maydis.
# mailto:flora.banuett@csulb.edu
# csulb.edu
# Renaud Berlemont, Ph.D.
# mailto:renaud.berlemont@csulb.edu
# https://csulb.academia.edu/RenaudBerlemont
# Judy A. Brusslan, Ph.D.
# Plant molecular biology.
# mailto:judy.bruss@csulb.edu
# http://web.csulb.edu/~bruss/
# Theoretical and empirical evolutionary biology.
# mailto:ashley.carter@csulb.edu
# http://web.csulb.edu/%7eacarter3/index.html
# Jesse Dillon, Ph.D.
# Microbial ecology and evolution.
# mailto:jesse.dillon@csulb.edu
# http://web.csulb.edu/~jdillon/
# Elizabeth D. Eldon, Ph.D
# mailto:e.eldon@csulb.edu
# csulb.edu
# Amanda E. Fisher, Ph.D.
# csulb.edu
# Deborah A. Fraser Ph.D.
# mailto:deborah.fraser@csulb.edu
# csulb.edu
# Editte Gharakhanian, Ph.D.
# Molecular cell biology.
# mailto:e.ghara@csulb.edu
# http://web.csulb.edu/labs/GharakhanianLab/
# Michael Harris, Ph.D.
# Physiology.
# mailto:michael.harris2@csulb.edu
# mailto:erika.holland@csulb.edu
# Erika Holland, Ph.D.
# Aquatic Toxicology.
# mailto:erika.holland@csulb.edu
# mailto:Darren.Johnson@csulb.edu
# Darren Johnson, Ph.D.
#  Ecology and evolutionary biology of reef fishes.
# mailto:Darren.Johnson@csulb.edu
# http://darrenwjohnson.weebly.com
# Sandy Kawano, Ph.D.
# Comparative physiology, biomechanics, and morphology of vertebrates.
# mailto:sandy.kawano@csulb.edu
# csulb.edu
# Balwant S. Khatra, Ph.D.
# Metabolic regulation.
# mailto:balwant.khatra@csulb.edu
# csulb.edu
# Lisa S. Klig, Ph.D.
# Molecular genetics and bioinformatics.
# mailto:ls.klig@csulb.edu
# csulb.edu
# Kay Lee-Fruman, Ph.D.
#  Cancer cell biology/immunology.
# mailto:kay.lee-fruman@csulb.edu
# csulb.edu
# Brian Livingston, Ph.D.
#  Development and Evolution.
# mailto:brian.livingston@csulb.edu
# http://web.csulb.edu/~blivings/
# Christopher G. Lowe, Ph.D.
# Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.
# mailto:chris.lowe@csulb.edu
# http://www.csulb.edu/shark-lab
#
#
#
#
# Douglas Pace, Ph.D.
#  Ecological Physiology.
# mailto:Douglas.Pace@csulb.edu
# csulb.edu
# Bruno Pernet, Ph.D.
# . Marine invertebrate biology.
# mailto:bruno.pernet@csulb.edu
# http://web.csulb.edu/~bpernet
# Bryan Rourke, Ph.D.
# Integrative animal physiology.
# mailto:bryan.rourke@csulb.edu
# http://web.csulb.edu/~brourke
# Kevin Sinchak, Ph.D.
# Reproductive behavioral neuroendocrinology; neuroscience and neurosteroids.
# mailto:kevin.sinchak@csulb.edu
# csulb.edu
# Ted Stankowich, Ph.D.
# Evolutionary Behavioral Ecology.
# mailto:Theodore.Stankowich@csulb.edu
# http://web.csulb.edu/~tstankow/
# Houng-Wei Tsai, Ph.D.
# Epigenetic neuroendocrinology.
# mailto:houng-wei.tsai@csulb.edu
# http://csulb.edu/%7ehtsai/index.html
# Dessie L. Underwood, Ph.D.
#  Insect biology.
# mailto:dessie.underwood@csulb.edu
# http://streamecologyassessmentlab.weebly.com/
# Christine Whitcraft, Ph.D.
# Wetlands Ecology.
# mailto:christine.whitcraft@csulb.edu
# http://web.csulb.edu/~cwhitcra/
# Raymond R. Wilson, Ph.D.
# Marine ichthyology.
# mailto:ray.wilson@csulb.edu
# csulb.edu
# Kelly Young, Ph.D.
# Reproductive biologist.
# mailto:kelly.young@csulb.edu
# csulb.edu
# Mason X. Zhang, Ph.D.
#  Host-pathogen interactions.
# mailto:mason.zhang@csulb.edu
# csulb.edu

# %% [markdown]
# # Officially running the scrape

# %%
import pandas as pd

df = pd.DataFrame(columns=['name', 'description', 'email', 'website'])

df
# Out:
# Empty DataFrame
# Columns: [name, description, email, website]
# Index: []

# %%
matrix = []

for item in soup.find_all('p')[1:]:
    
    new_entry = []
    
    try:
        new_entry.append(item.find('strong').get_text())
    except:
        try:
            new_entry.append(item.find('b').get_text())
        except:
            new_entry.append(' ')
    
    try:
        new_entry.append(item.find('span').get_text())
    except:
        new_entry.append(' ')
    
    try:
        new_entry.append(item.find('a').get("href")[7:])
    except:
        new_entry.append(' ')
    
    
    try:
        new_entry.append(item.find_all('a')[1].get("href"))
    except:
        new_entry.append("csulb.edu")
                
        
    matrix.append(new_entry)

# %%
matrix
# Out:
# [['Bengt J. Allen, Ph.D.',
#   'Marine Community Ecology. ',
#   'bengt.allen@csulb.edu',
#   'http://web.csulb.edu/%7ebjallen/Site/Home.html'],
#  ['James W. Archie, Ph.D.',
#   'Evolutionary and Ecological Genetics; Population Biology; Biostatistics. ',
#   ' james.archie@csulb.edu',
#   'csulb.edu'],
#  ['Flora Banuett, Ph.D.',
#   ' Fungal genetics and cell biology. Molecular mechanisms of cell morphogenesis in the fungus Ustilago maydis.',
#   'flora.banuett@csulb.edu',
#   'csulb.edu'],
#  ['Renaud Berlemont, Ph.D.',
#   ' ',
#   'renaud.berlemont@csulb.edu',
#   'https://csulb.academia.edu/RenaudBerlemont'],
#  ['Judy A. Brusslan, Ph.D. ',
#   'Plant molecular biology.',
#   'judy.bruss@csulb.edu',
#   'http://web.csulb.edu/~bruss/'],
#  ['Ashley Carter, Ph.D.\xa0 ',
#   'Theoretical and empirical evolutionary biology.\xa0',
#   'ashley.carter@csulb.edu',
#   'http://web.csulb.edu/%7eacarter3/index.html'],
#  ['Jesse Dillon, Ph.D. ',
#   'Microbial ecology and evolution. ',
#   'jesse.dillon@csulb.edu',
#   'http://web.csulb.edu/~jdillon/'],
#  ['Elizabeth D. Eldon, Ph.D', ' ', 'e.eldon@csulb.edu', 'csulb.edu'],
#  ['Amanda E. Fisher, Ph.D.', ' ', ' ', 'csulb.edu'],
#  ['Deborah A. Fraser Ph.D. ', ' ', 'deborah.fraser@csulb.edu', 'csulb.edu'],
#  ['Editte Gharakhanian, Ph.D.',
#   'Molecular cell biology.',
#   'e.ghara@csulb.edu',
#   'http://web.csulb.edu/labs/GharakhanianLab/'],
#  ['Michael Harris, Ph.D.',
#   'Physiology.',
#   'michael.harris2@csulb.edu',
#   'mailto:erika.holland@csulb.edu'],
#  ['Erika Holland, Ph.D.',
#   'Aquatic Toxicology.',
#   'erika.holland@csulb.edu',
#   'mailto:Darren.Johnson@csulb.edu'],
#  ['Darren Johnson, Ph.D.',
#   ' Ecology and evolutionary biology of reef fishes.  ',
#   'Darren.Johnson@csulb.edu',
#   'http://darrenwjohnson.weebly.com'],
#  ['Sandy Kawano, Ph.D. ',
#   'Comparative physiology, biomechanics, and morphology of vertebrates.',
#   'sandy.kawano@csulb.edu',
#   'csulb.edu'],
#  ['Balwant S. Khatra, Ph.D.',
#   'Metabolic regulation.',
#   'balwant.khatra@csulb.edu',
#   'csulb.edu'],
#  ['Lisa S. Klig, Ph.D. ',
#   'Molecular genetics and bioinformatics.',
#   'ls.klig@csulb.edu',
#   'csulb.edu'],
#  ['Kay Lee-Fruman, Ph.D.',
#   ' Cancer cell biology/immunology.',
#   'kay.lee-fruman@csulb.edu',
#   'csulb.edu'],
#  ['Brian Livingston, Ph.D. ',
#   ' Development and Evolution.',
#   'brian.livingston@csulb.edu',
#   'http://web.csulb.edu/~blivings/'],
#  ['Christopher G. Lowe, Ph.D.',
#   'Physiological and behavioral ecology of teleost gamefishes and elasmobranchs.',
#   'chris.lowe@csulb.edu',
#   'http://www.csulb.edu/shark-lab'],
#  ['', ' ', '', ''],
#  ['Douglas Pace, Ph.D. ',
#   ' Ecological Physiology.',
#   'Douglas.Pace@csulb.edu',
#   'csulb.edu'],
#  ['Bruno Pernet, Ph.D. ',
#   '. Marine invertebrate biology.',
#   'bruno.pernet@csulb.edu',
#   'http://web.csulb.edu/~bpernet'],
#  ['Bryan Rourke, Ph.D.',
#   'Integrative animal physiology.',
#   'bryan.rourke@csulb.edu',
#   'http://web.csulb.edu/~brourke'],
#  ['Kevin Sinchak, Ph.D.',
#   'Reproductive behavioral neuroendocrinology; neuroscience and neurosteroids.',
#   'kevin.sinchak@csulb.edu',
#   'csulb.edu'],
#  ['Ted Stankowich, Ph.D.',
#   'Evolutionary Behavioral Ecology.',
#   'Theodore.Stankowich@csulb.edu',
#   'http://web.csulb.edu/~tstankow/'],
#  ['Houng-Wei Tsai, Ph.D. ',
#   'Epigenetic neuroendocrinology. ',
#   'houng-wei.tsai@csulb.edu',
#   'http://csulb.edu/%7ehtsai/index.html'],
#  ['Dessie L. Underwood, Ph.D.',
#   ' Insect biology.',
#   'dessie.underwood@csulb.edu',
#   'http://streamecologyassessmentlab.weebly.com/'],
#  ['Christine Whitcraft, Ph.D.',
#   'Wetlands Ecology.',
#   'christine.whitcraft@csulb.edu',
#   'http://web.csulb.edu/~cwhitcra/'],
#  ['Raymond R. Wilson, Ph.D.',
#   'Marine ichthyology.',
#   'ray.wilson@csulb.edu',
#   'csulb.edu'],
#  ['Kelly Young, Ph.D. ',
#   'Reproductive biologist.',
#   'kelly.young@csulb.edu',
#   'csulb.edu'],
#  ['Mason X. Zhang, Ph.D. ',
#   ' Host-pathogen interactions.',
#   'mason.zhang@csulb.edu',
#   'csulb.edu']]

# %%
df = pd.DataFrame(matrix, columns=['name', 'description', 'email', 'website'])
df
# Out:
#                           name  \
# 0        Bengt J. Allen, Ph.D.
# 1       James W. Archie, Ph.D.
# 2         Flora Banuett, Ph.D.
# 3      Renaud Berlemont, Ph.D.
# 4     Judy A. Brusslan, Ph.D.
# 5       Ashley Carter, Ph.D.
# 6         Jesse Dillon, Ph.D.
# 7     Elizabeth D. Eldon, Ph.D
# 8      Amanda E. Fisher, Ph.D.
# 9     Deborah A. Fraser Ph.D.
# 10  Editte Gharakhanian, Ph.D.
# 11       Michael Harris, Ph.D.
# 12        Erika Holland, Ph.D.
# 13       Darren Johnson, Ph.D.
# 14        Sandy Kawano, Ph.D.
# 15    Balwant S. Khatra, Ph.D.
# 16        Lisa S. Klig, Ph.D.
# 17       Kay Lee-Fruman, Ph.D.
# 18    Brian Livingston, Ph.D.
# 19  Christopher G. Lowe, Ph.D.
# 20
# 21        Douglas Pace, Ph.D.
# 22        Bruno Pernet, Ph.D.
# 23         Bryan Rourke, Ph.D.
# 24        Kevin Sinchak, Ph.D.
# 25       Ted Stankowich, Ph.D.
# 26      Houng-Wei Tsai, Ph.D.
# 27  Dessie L. Underwood, Ph.D.
# 28  Christine Whitcraft, Ph.D.
# 29    Raymond R. Wilson, Ph.D.
# 30         Kelly Young, Ph.D.
# 31      Mason X. Zhang, Ph.D.
#
#                                           description  \
# 0                          Marine Community Ecology.
# 1   Evolutionary and Ecological Genetics; Populati...
# 2    Fungal genetics and cell biology. Molecular m...
# 3
# 4                            Plant molecular biology.
# 5    Theoretical and empirical evolutionary biology.
# 6                   Microbial ecology and evolution.
# 7
# 8
# 9
# 10                            Molecular cell biology.
# 11                                        Physiology.
# 12                                Aquatic Toxicology.
# 13   Ecology and evolutionary biology of reef fish...
# 14  Comparative physiology, biomechanics, and morp...
# 15                              Metabolic regulation.
# 16             Molecular genetics and bioinformatics.
# 17                    Cancer cell biology/immunology.
# 18                         Development and Evolution.
# 19  Physiological and behavioral ecology of teleos...
# 20
# 21                             Ecological Physiology.
# 22                     . Marine invertebrate biology.
# 23                     Integrative animal physiology.
# 24  Reproductive behavioral neuroendocrinology; ne...
# 25                   Evolutionary Behavioral Ecology.
# 26                    Epigenetic neuroendocrinology.
# 27                                    Insect biology.
# 28                                  Wetlands Ecology.
# 29                                Marine ichthyology.
# 30                            Reproductive biologist.
# 31                        Host-pathogen interactions.
#
#                             email  \
# 0           bengt.allen@csulb.edu
# 1          james.archie@csulb.edu
# 2         flora.banuett@csulb.edu
# 3      renaud.berlemont@csulb.edu
# 4            judy.bruss@csulb.edu
# 5         ashley.carter@csulb.edu
# 6          jesse.dillon@csulb.edu
# 7               e.eldon@csulb.edu
# 8
# 9        deborah.fraser@csulb.edu
# 10              e.ghara@csulb.edu
# 11      michael.harris2@csulb.edu
# 12        erika.holland@csulb.edu
# 13       Darren.Johnson@csulb.edu
# 14         sandy.kawano@csulb.edu
# 15       balwant.khatra@csulb.edu
# 16              ls.klig@csulb.edu
# 17       kay.lee-fruman@csulb.edu
# 18     brian.livingston@csulb.edu
# 19           chris.lowe@csulb.edu
# 20
# 21         Douglas.Pace@csulb.edu
# 22         bruno.pernet@csulb.edu
# 23         bryan.rourke@csulb.edu
# 24        kevin.sinchak@csulb.edu
# 25  Theodore.Stankowich@csulb.edu
# 26       houng-wei.tsai@csulb.edu
# 27     dessie.underwood@csulb.edu
# 28  christine.whitcraft@csulb.edu
# 29           ray.wilson@csulb.edu
# 30          kelly.young@csulb.edu
# 31          mason.zhang@csulb.edu
#
#                                            website
# 0   http://web.csulb.edu/%7ebjallen/Site/Home.html
# 1                                        csulb.edu
# 2                                        csulb.edu
# 3       https://csulb.academia.edu/RenaudBerlemont
# 4                     http://web.csulb.edu/~bruss/
# 5      http://web.csulb.edu/%7eacarter3/index.html
# 6                   http://web.csulb.edu/~jdillon/
# 7                                        csulb.edu
# 8                                        csulb.edu
# 9                                        csulb.edu
# 10      http://web.csulb.edu/labs/GharakhanianLab/
# 11                  mailto:erika.holland@csulb.edu
# 12                 mailto:Darren.Johnson@csulb.edu
# 13                http://darrenwjohnson.weebly.com
# 14                                       csulb.edu
# 15                                       csulb.edu
# 16                                       csulb.edu
# 17                                       csulb.edu
# 18                 http://web.csulb.edu/~blivings/
# 19                  http://www.csulb.edu/shark-lab
# 20
# 21                                       csulb.edu
# 22                   http://web.csulb.edu/~bpernet
# 23                   http://web.csulb.edu/~brourke
# 24                                       csulb.edu
# 25                 http://web.csulb.edu/~tstankow/
# 26            http://csulb.edu/%7ehtsai/index.html
# 27   http://streamecologyassessmentlab.weebly.com/
# 28                 http://web.csulb.edu/~cwhitcra/
# 29                                       csulb.edu
# 30                                       csulb.edu
# 31                                       csulb.edu

# %% [markdown]
# # Cleaning minor mistakes in the data

# %%
df.at[11, 'website'] = ''

# %%
df.at[12, 'website'] = ''

# %%
df
# Out:
#                           name  \
# 0        Bengt J. Allen, Ph.D.
# 1       James W. Archie, Ph.D.
# 2         Flora Banuett, Ph.D.
# 3      Renaud Berlemont, Ph.D.
# 4     Judy A. Brusslan, Ph.D.
# 5       Ashley Carter, Ph.D.
# 6         Jesse Dillon, Ph.D.
# 7     Elizabeth D. Eldon, Ph.D
# 8      Amanda E. Fisher, Ph.D.
# 9     Deborah A. Fraser Ph.D.
# 10  Editte Gharakhanian, Ph.D.
# 11       Michael Harris, Ph.D.
# 12        Erika Holland, Ph.D.
# 13       Darren Johnson, Ph.D.
# 14        Sandy Kawano, Ph.D.
# 15    Balwant S. Khatra, Ph.D.
# 16        Lisa S. Klig, Ph.D.
# 17       Kay Lee-Fruman, Ph.D.
# 18    Brian Livingston, Ph.D.
# 19  Christopher G. Lowe, Ph.D.
# 20
# 21        Douglas Pace, Ph.D.
# 22        Bruno Pernet, Ph.D.
# 23         Bryan Rourke, Ph.D.
# 24        Kevin Sinchak, Ph.D.
# 25       Ted Stankowich, Ph.D.
# 26      Houng-Wei Tsai, Ph.D.
# 27  Dessie L. Underwood, Ph.D.
# 28  Christine Whitcraft, Ph.D.
# 29    Raymond R. Wilson, Ph.D.
# 30         Kelly Young, Ph.D.
# 31      Mason X. Zhang, Ph.D.
#
#                                           description  \
# 0                          Marine Community Ecology.
# 1   Evolutionary and Ecological Genetics; Populati...
# 2    Fungal genetics and cell biology. Molecular m...
# 3
# 4                            Plant molecular biology.
# 5    Theoretical and empirical evolutionary biology.
# 6                   Microbial ecology and evolution.
# 7
# 8
# 9
# 10                            Molecular cell biology.
# 11                                        Physiology.
# 12                                Aquatic Toxicology.
# 13   Ecology and evolutionary biology of reef fish...
# 14  Comparative physiology, biomechanics, and morp...
# 15                              Metabolic regulation.
# 16             Molecular genetics and bioinformatics.
# 17                    Cancer cell biology/immunology.
# 18                         Development and Evolution.
# 19  Physiological and behavioral ecology of teleos...
# 20
# 21                             Ecological Physiology.
# 22                     . Marine invertebrate biology.
# 23                     Integrative animal physiology.
# 24  Reproductive behavioral neuroendocrinology; ne...
# 25                   Evolutionary Behavioral Ecology.
# 26                    Epigenetic neuroendocrinology.
# 27                                    Insect biology.
# 28                                  Wetlands Ecology.
# 29                                Marine ichthyology.
# 30                            Reproductive biologist.
# 31                        Host-pathogen interactions.
#
#                             email  \
# 0           bengt.allen@csulb.edu
# 1          james.archie@csulb.edu
# 2         flora.banuett@csulb.edu
# 3      renaud.berlemont@csulb.edu
# 4            judy.bruss@csulb.edu
# 5         ashley.carter@csulb.edu
# 6          jesse.dillon@csulb.edu
# 7               e.eldon@csulb.edu
# 8
# 9        deborah.fraser@csulb.edu
# 10              e.ghara@csulb.edu
# 11      michael.harris2@csulb.edu
# 12        erika.holland@csulb.edu
# 13       Darren.Johnson@csulb.edu
# 14         sandy.kawano@csulb.edu
# 15       balwant.khatra@csulb.edu
# 16              ls.klig@csulb.edu
# 17       kay.lee-fruman@csulb.edu
# 18     brian.livingston@csulb.edu
# 19           chris.lowe@csulb.edu
# 20
# 21         Douglas.Pace@csulb.edu
# 22         bruno.pernet@csulb.edu
# 23         bryan.rourke@csulb.edu
# 24        kevin.sinchak@csulb.edu
# 25  Theodore.Stankowich@csulb.edu
# 26       houng-wei.tsai@csulb.edu
# 27     dessie.underwood@csulb.edu
# 28  christine.whitcraft@csulb.edu
# 29           ray.wilson@csulb.edu
# 30          kelly.young@csulb.edu
# 31          mason.zhang@csulb.edu
#
#                                            website
# 0   http://web.csulb.edu/%7ebjallen/Site/Home.html
# 1                                        csulb.edu
# 2                                        csulb.edu
# 3       https://csulb.academia.edu/RenaudBerlemont
# 4                     http://web.csulb.edu/~bruss/
# 5      http://web.csulb.edu/%7eacarter3/index.html
# 6                   http://web.csulb.edu/~jdillon/
# 7                                        csulb.edu
# 8                                        csulb.edu
# 9                                        csulb.edu
# 10      http://web.csulb.edu/labs/GharakhanianLab/
# 11
# 12
# 13                http://darrenwjohnson.weebly.com
# 14                                       csulb.edu
# 15                                       csulb.edu
# 16                                       csulb.edu
# 17                                       csulb.edu
# 18                 http://web.csulb.edu/~blivings/
# 19                  http://www.csulb.edu/shark-lab
# 20
# 21                                       csulb.edu
# 22                   http://web.csulb.edu/~bpernet
# 23                   http://web.csulb.edu/~brourke
# 24                                       csulb.edu
# 25                 http://web.csulb.edu/~tstankow/
# 26            http://csulb.edu/%7ehtsai/index.html
# 27   http://streamecologyassessmentlab.weebly.com/
# 28                 http://web.csulb.edu/~cwhitcra/
# 29                                       csulb.edu
# 30                                       csulb.edu
# 31                                       csulb.edu

# %% [markdown]
# # Export to CSV

# %%
df.to_csv("Web Scrape Cal State Long Beach Biology Research Faculty.csv")
